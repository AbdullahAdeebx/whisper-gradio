# %% [markdown]
# ---
# 🖋 **Author**: [Abdullah Adeeb](https://github.com/AbdullahAdeebx)
#
# 😎 **Support the Project**:
#
# If you find this project useful, please let me know!
#
# <a href="https://x.com/AbdullahAdeebi" target="_blank">X (Twitter)</a>
# <a href="mailto:abdullah@abdullahadeeb.xyz" target="_blank">Email</a>
# <a href="https://github.com/AbdullahAdeebx" target="_blank">GitHub</a>
#
# ---

# %%
#@title #Installation
#@markdown This cell will install dependencies.
# !git clone https://github.com/AbdullahAdeebx/whisper-gradio.git
# %cd whisper-gradio/
# !pip install -r requirements.txt
# !sudo apt install $(cat packages.txt)
# Out:
# fatal: destination path 'whisper-gradio' already exists and is not an empty directory.
# /content/whisper-gradio
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 15.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 MB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.6/320.6 kB 30.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 111.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.4 MB/s eta 0:00:00
# ...

# %%
#@title #Run
#@markdown Once the installation is complete, you can use public URL that is displayed.
# !python app.py
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://4e277cf609aac965f4.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 100%|█████████████████████████████████████| 1.51G/1.51G [00:49<00:00, 33.0MiB/s]
# ...
